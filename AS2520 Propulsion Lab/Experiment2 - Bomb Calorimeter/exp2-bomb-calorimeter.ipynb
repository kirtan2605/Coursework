# %%
import pandas as pd

df = pd.read_excel (r'../input/bombcalorimeter-data/Aviation-Turbine-Fuel-Data.ods')
print (df)

# %%
columns_list = df.columns.values.tolist()
print(columns_list)

# %% [markdown]
# It is important to note that there is a space after Time and thus, when calling this attribute via the column name, we need to mention the space as well!!

# %%
df['Temperature']    # or df.Temperature

# %%
df['Time ']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = df['Time ']
y = df['Temperature']
plt.plot(x,y,'-')
plt.xlim(0, 950, 50)
plt.ylim(28,33, 0.5)
plt.title("Aviation Turbine Fuel")
plt.xlabel("Time (in s)")
plt.ylabel("Temperature (in K)")
plt.grid(color = 'green',which = 'both', linestyle = '--', linewidth = 0.5)

#specify x-axis locations
y_ticks = [ x for x in range(28,34)]
#specify x-axis labels
y_labels = ['A', 'B', 'C', 'D', 'E','F'] 

#add x-axis values to plot
plt.yticks(ticks=y_ticks, labels=y_labels)

plt.show()
